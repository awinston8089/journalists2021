# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import pymongo
from matplotlib import pyplot as plt

# %%
#Importing 2015 CSV
Happiness_2015_df = pd.read_csv("Resources/2015.csv")
Happiness_2015_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
Happiness_2015_df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
Happiness_2015_df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
Happiness_2015_df.count()
# Out:
# Country                          158
# Region                           158
# Happiness Rank                   158
# Happiness Score                  158
# Standard Error                   158
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         158
# Freedom                          158
# Trust (Government Corruption)    158
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %%
#Reading the 2016 CSV File
Happiness_2016_df = pd.read_csv("Resources/2016.csv")
Happiness_2016_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
# 3                   1.57744  1.12690                   0.79579  0.59609
# 4                   1.40598  1.13464                   0.81091  0.57104
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# 1                        0.41203     0.28083            2.69463
# 2                        0.14975     0.47678            2.83137
# 3                        0.35776     0.37895            2.66465
# 4                        0.41004     0.25492            2.82596

# %%
#Reading the 2016 CSV File
Happiness_2016_df = pd.read_csv("Resources/2016.csv")
Happiness_2016_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
# 3                   1.57744  1.12690                   0.79579  0.59609
# 4                   1.40598  1.13464                   0.81091  0.57104
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# 1                        0.41203     0.28083            2.69463
# 2                        0.14975     0.47678            2.83137
# 3                        0.35776     0.37895            2.66465
# 4                        0.41004     0.25492            2.82596

# %%
Happiness_2016_df.count()
# Out:
# Country                          157
# Region                           157
# Happiness Rank                   157
# Happiness Score                  157
# Lower Confidence Interval        157
# Upper Confidence Interval        157
# Economy (GDP per Capita)         157
# Family                           157
# Health (Life Expectancy)         157
# Freedom                          157
# Trust (Government Corruption)    157
# Generosity                       157
# Dystopia Residual                157
# dtype: int64

# %%
#Reading the 2017 CSV File
Happiness_2017_df = pd.read_csv("Resources/2017.csv")
Happiness_2017_df.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707
# 2    0.475540                       0.153527           2.322715
# 3    0.290549                       0.367007           2.276716
# 4    0.245483                       0.382612           2.430182

# %%
Happiness_2017_df.count()
# Out:
# Country                          155
# Happiness.Rank                   155
# Happiness.Score                  155
# Whisker.high                     155
# Whisker.low                      155
# Economy..GDP.per.Capita.         155
# Family                           155
# Health..Life.Expectancy.         155
# Freedom                          155
# Generosity                       155
# Trust..Government.Corruption.    155
# Dystopia.Residual                155
# dtype: int64

# %%
Happiness_2017_df.count()
# Out:
# Country                          155
# Happiness.Rank                   155
# Happiness.Score                  155
# Whisker.high                     155
# Whisker.low                      155
# Economy..GDP.per.Capita.         155
# Family                           155
# Health..Life.Expectancy.         155
# Freedom                          155
# Generosity                       155
# Trust..Government.Corruption.    155
# Dystopia.Residual                155
# dtype: int64

# %%
#Reading the 2018 CSV File
Happiness_2018_df = pd.read_csv("Resources/2018.csv")
Happiness_2018_df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# 2                      0.408
# 3                      0.138
# 4                      0.357

# %%
Happiness_2018_df.count()
# Out:
# Overall rank                    156
# Country or region               156
# Score                           156
# GDP per capita                  156
# Social support                  156
# Healthy life expectancy         156
# Freedom to make life choices    156
# Generosity                      156
# Perceptions of corruption       155
# dtype: int64

# %%
Happiness_2018_df.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
#Reading the 2018 CSV File
Happiness_2019_df = pd.read_csv("Resources/2019.csv")
Happiness_2019_df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %%
Happiness_2019_df.count()
# Out:
# Overall rank                    156
# Country or region               156
# Score                           156
# GDP per capita                  156
# Social support                  156
# Healthy life expectancy         156
# Freedom to make life choices    156
# Generosity                      156
# Perceptions of corruption       156
# dtype: int64

# %%
Happiness_2020_df = pd.read_csv("Resources/2020.csv")
Happiness_2020_df.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# 3              10.772559        0.974670                73.000000
# 4              11.087804        0.952487                73.200783
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                      0.949172   -0.059482                   0.195445
# 1                      0.951444    0.066202                   0.168489
# 2                      0.921337    0.105911                   0.303728
# 3                      0.948892    0.246944                   0.711710
# 4                      0.955750    0.134533                   0.263218
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                  1.972317                          1.285190
# 1                  1.972317                          1.326949
# 2                  1.972317                          1.390774
# 3                  1.972317                          1.326502
# 4                  1.972317                          1.424207
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                      1.499526                               0.961271
# 1                      1.503449                               0.979333
# 2                      1.472403                               1.040533
# 3                      1.547567                               1.000843
# 4                      1.495173                               1.008072
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                    0.662317                  0.159670
# 1                                    0.665040                  0.242793
# 2                                    0.628954                  0.269056
# 3                                    0.661981                  0.362330
# 4                                    0.670201                  0.287985
#
#    Explained by: Perceptions of corruption  Dystopia + residual
# 0                                 0.477857             2.762835
# 1                                 0.495260             2.432741
# 2                                 0.407946             2.350267
# 3                                 0.144541             2.460688
# 4                                 0.434101             2.168266

# %%
Happiness_2020_df.count()
# Out:
# Country name                                  153
# Regional indicator                            153
# Ladder score                                  153
# Standard error of ladder score                153
# upperwhisker                                  153
# lowerwhisker                                  153
# Logged GDP per capita                         153
# Social support                                153
# Healthy life expectancy                       153
# Freedom to make life choices                  153
# Generosity                                    153
# Perceptions of corruption                     153
# Ladder score in Dystopia                      153
# Explained by: Log GDP per capita              153
# Explained by: Social support                  153
# Explained by: Healthy life expectancy         153
# Explained by: Freedom to make life choices    153
# Explained by: Generosity                      153
# Explained by: Perceptions of corruption       153
# Dystopia + residual                           153
# dtype: int64

# %% [markdown]
# ## Reading and Cleaning the Journalist Death CSV (1992 - 2020)

# %%
# Reading the Journalist Death CSV

journalist_death_df = pd.read_csv("Resources/journalistdeath.csv")
journalist_death_df.head()
# Out:
#    year combinedStatus                   fullName  sortName  \
# 0  2018      Confirmed         Abadullah Hananzai       NaN
# 1  1998      Confirmed                 Abay Hailu       NaN
# 2  2012      Confirmed       Abd al-Karim al-Ezzo       NaN
# 3  1996      Confirmed         Abdallah Bouhachek       NaN
# 4  2013      Confirmed  Abdel Aziz Mahmoud Hasoun       NaN
#
#   primaryNationality secondaryNationality  tertiaryNationality gender  \
# 0        Afghanistan                  NaN                  NaN   Male
# 1           Ethiopia                  NaN                  NaN   Male
# 2              Syria                  NaN                  NaN   Male
# 3            Algeria                  NaN                  NaN   Male
# 4              Syria                  NaN                  NaN   Male
#
#   photoUrl photoCredit  ... threatened charges motive lengthOfSentence  \
# 0      NaN         NaN  ...         No     NaN    NaN              NaN
# 1      NaN         NaN  ...        NaN     NaN    NaN              NaN
# 2      NaN         NaN  ...        NaN     NaN    NaN              NaN
# 3      NaN         NaN  ...         No     NaN    NaN              NaN
# 4      NaN         NaN  ...        NaN     NaN    NaN              NaN
#
#   healthProblems impCountry entry sentenceDate sentence locationImprisoned
# 0            NaN        NaN   NaN          NaN      NaN                NaN
# 1            NaN        NaN   NaN          NaN      NaN                NaN
# 2            NaN        NaN   NaN          NaN      NaN                NaN
# 3            NaN        NaN   NaN          NaN      NaN                NaN
# 4            NaN        NaN   NaN          NaN      NaN                NaN
#
# [5 rows x 43 columns]

# %%
journalist_death_df.columns
# Out:
# Index(['year', 'combinedStatus', 'fullName', 'sortName', 'primaryNationality',
#        'secondaryNationality', 'tertiaryNationality', 'gender', 'photoUrl',
#        'photoCredit', 'type', 'lastStatus', 'typeOfDeath', 'status',
#        'employedAs', 'organizations', 'jobs', 'coverage', 'mediums', 'country',
#        'location', 'region', 'state', 'locality', 'province', 'localOrForeign',
#        'sourcesOfFire', 'motiveConfirmed', 'accountabilityCrossfire',
#        'accountabilityAssignment', 'impunityMurder', 'tortured', 'captive',
#        'threatened', 'charges', 'motive', 'lengthOfSentence', 'healthProblems',
#        'impCountry', 'entry', 'sentenceDate', 'sentence',
#        'locationImprisoned'],
#       dtype='object')

# %%
journal_death_dropone_df = journalist_death_df.drop(['primaryNationality','secondaryNationality','tertiaryNationality','photoUrl','photoCredit', 'lengthOfSentence', 'healthProblems'], axis=1)

# %%
journal_death_dropone_df.head()
# Out:
#    year combinedStatus                   fullName  sortName gender  \
# 0  2018      Confirmed         Abadullah Hananzai       NaN   Male
# 1  1998      Confirmed                 Abay Hailu       NaN   Male
# 2  2012      Confirmed       Abd al-Karim al-Ezzo       NaN   Male
# 3  1996      Confirmed         Abdallah Bouhachek       NaN   Male
# 4  2013      Confirmed  Abdel Aziz Mahmoud Hasoun       NaN   Male
#
#          type lastStatus           typeOfDeath  status employedAs  ...  \
# 0  Journalist     Killed                Murder  Killed      Staff  ...
# 1  Journalist        NaN  Dangerous Assignment  Killed      Staff  ...
# 2  Journalist        NaN             Crossfire  Killed  Freelance  ...
# 3  Journalist        NaN                Murder  Killed      Staff  ...
# 4  Journalist        NaN             Crossfire  Killed      Staff  ...
#
#   tortured captive threatened charges motive impCountry entry sentenceDate  \
# 0       No      No         No     NaN    NaN        NaN   NaN          NaN
# 1      NaN     NaN        NaN     NaN    NaN        NaN   NaN          NaN
# 2      NaN     NaN        NaN     NaN    NaN        NaN   NaN          NaN
# 3       No      No         No     NaN    NaN        NaN   NaN          NaN
# 4      NaN     NaN        NaN     NaN    NaN        NaN   NaN          NaN
#
#   sentence locationImprisoned
# 0      NaN                NaN
# 1      NaN                NaN
# 2      NaN                NaN
# 3      NaN                NaN
# 4      NaN                NaN
#
# [5 rows x 36 columns]

# %%
journal_death_dropone_df.columns
# Out:
# Index(['year', 'combinedStatus', 'fullName', 'sortName', 'gender', 'type',
#        'lastStatus', 'typeOfDeath', 'status', 'employedAs', 'organizations',
#        'jobs', 'coverage', 'mediums', 'country', 'location', 'region', 'state',
#        'locality', 'province', 'localOrForeign', 'sourcesOfFire',
#        'motiveConfirmed', 'accountabilityCrossfire',
#        'accountabilityAssignment', 'impunityMurder', 'tortured', 'captive',
#        'threatened', 'charges', 'motive', 'impCountry', 'entry',
#        'sentenceDate', 'sentence', 'locationImprisoned'],
#       dtype='object')

# %%
journal_death_droptwo_df = journal_death_dropone_df.drop(['charges', 'motive', 'impCountry', 'entry', 'sentenceDate', 'sentence', 'locationImprisoned'], axis=1)
journal_death_droptwo_df.head()
# Out:
#    year combinedStatus                   fullName  sortName gender  \
# 0  2018      Confirmed         Abadullah Hananzai       NaN   Male
# 1  1998      Confirmed                 Abay Hailu       NaN   Male
# 2  2012      Confirmed       Abd al-Karim al-Ezzo       NaN   Male
# 3  1996      Confirmed         Abdallah Bouhachek       NaN   Male
# 4  2013      Confirmed  Abdel Aziz Mahmoud Hasoun       NaN   Male
#
#          type lastStatus           typeOfDeath  status employedAs  ...  \
# 0  Journalist     Killed                Murder  Killed      Staff  ...
# 1  Journalist        NaN  Dangerous Assignment  Killed      Staff  ...
# 2  Journalist        NaN             Crossfire  Killed  Freelance  ...
# 3  Journalist        NaN                Murder  Killed      Staff  ...
# 4  Journalist        NaN             Crossfire  Killed      Staff  ...
#
#   province localOrForeign         sourcesOfFire motiveConfirmed  \
# 0      NaN          Local       Political Group       Confirmed
# 1      NaN          Local  Government Officials       Confirmed
# 2      NaN          Local    Military Officials       Confirmed
# 3      NaN          Local                   NaN       Confirmed
# 4      NaN          Local    Military Officials       Confirmed
#
#   accountabilityCrossfire accountabilityAssignment     impunityMurder  \
# 0                     NaN                      NaN  Complete Impunity
# 1                     NaN                       No                NaN
# 2                     NaN                      NaN                NaN
# 3                     NaN                      NaN  Complete Impunity
# 4                     NaN                      NaN                NaN
#
#   tortured captive threatened
# 0       No      No         No
# 1      NaN     NaN        NaN
# 2      NaN     NaN        NaN
# 3       No      No         No
# 4      NaN     NaN        NaN
#
# [5 rows x 29 columns]

# %%
journal_death_droptwo_df.columns
# Out:
# Index(['year', 'combinedStatus', 'fullName', 'sortName', 'gender', 'type',
#        'lastStatus', 'typeOfDeath', 'status', 'employedAs', 'organizations',
#        'jobs', 'coverage', 'mediums', 'country', 'location', 'region', 'state',
#        'locality', 'province', 'localOrForeign', 'sourcesOfFire',
#        'motiveConfirmed', 'accountabilityCrossfire',
#        'accountabilityAssignment', 'impunityMurder', 'tortured', 'captive',
#        'threatened'],
#       dtype='object')

# %%
journal_death_dropthree_df = journal_death_droptwo_df.drop(['region','state','locality','province','localOrForeign', 'accountabilityCrossfire', 'accountabilityAssignment', 'tortured', 'captive', 'threatened'], axis=1)
journal_death_dropthree_df.head()
# Out:
#    year combinedStatus                   fullName  sortName gender  \
# 0  2018      Confirmed         Abadullah Hananzai       NaN   Male
# 1  1998      Confirmed                 Abay Hailu       NaN   Male
# 2  2012      Confirmed       Abd al-Karim al-Ezzo       NaN   Male
# 3  1996      Confirmed         Abdallah Bouhachek       NaN   Male
# 4  2013      Confirmed  Abdel Aziz Mahmoud Hasoun       NaN   Male
#
#          type lastStatus           typeOfDeath  status employedAs  \
# 0  Journalist     Killed                Murder  Killed      Staff
# 1  Journalist        NaN  Dangerous Assignment  Killed      Staff
# 2  Journalist        NaN             Crossfire  Killed  Freelance
# 3  Journalist        NaN                Murder  Killed      Staff
# 4  Journalist        NaN             Crossfire  Killed      Staff
#
#                                  organizations               jobs  \
# 0  Radio Azadi,Radio Free Europe/Radio Liberty           Producer
# 1                                       Agiere     Print Reporter
# 2                                    Freelance    Camera Operator
# 3                        Révolution et Travail             Editor
# 4                                  Masar Press  Internet Reporter
#
#                     coverage         mediums      country         location  \
# 0         Crime,Politics,War  Radio,Internet  Afghanistan            Kabul
# 1      Human Rights,Politics           Print     Ethiopia      Addis Ababa
# 2                        War        Internet        Syria             Homs
# 3                   Politics           Print      Algeria            Blida
# 4  Human Rights,Politics,War        Internet        Syria  Jobar, Damascus
#
#           sourcesOfFire motiveConfirmed     impunityMurder
# 0       Political Group       Confirmed  Complete Impunity
# 1  Government Officials       Confirmed                NaN
# 2    Military Officials       Confirmed                NaN
# 3                   NaN       Confirmed  Complete Impunity
# 4    Military Officials       Confirmed                NaN

# %%
journal_death_dropfour_df = journal_death_dropthree_df.drop(['fullName', 'sortName','lastStatus','organizations', 'impunityMurder'], axis=1)
journal_death_dropfour_df.head()
# Out:
#    year combinedStatus gender        type           typeOfDeath  status  \
# 0  2018      Confirmed   Male  Journalist                Murder  Killed
# 1  1998      Confirmed   Male  Journalist  Dangerous Assignment  Killed
# 2  2012      Confirmed   Male  Journalist             Crossfire  Killed
# 3  1996      Confirmed   Male  Journalist                Murder  Killed
# 4  2013      Confirmed   Male  Journalist             Crossfire  Killed
#
#   employedAs               jobs                   coverage         mediums  \
# 0      Staff           Producer         Crime,Politics,War  Radio,Internet
# 1      Staff     Print Reporter      Human Rights,Politics           Print
# 2  Freelance    Camera Operator                        War        Internet
# 3      Staff             Editor                   Politics           Print
# 4      Staff  Internet Reporter  Human Rights,Politics,War        Internet
#
#        country         location         sourcesOfFire motiveConfirmed
# 0  Afghanistan            Kabul       Political Group       Confirmed
# 1     Ethiopia      Addis Ababa  Government Officials       Confirmed
# 2        Syria             Homs    Military Officials       Confirmed
# 3      Algeria            Blida                   NaN       Confirmed
# 4        Syria  Jobar, Damascus    Military Officials       Confirmed

# %%
marks_list = journal_death_droptwo_df['gender'].tolist() 
  
# show the list 
print(marks_list)
# Out:
# ['Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', ...

# %%
# look for missing values
journal_death_dropfour_df.count()
# Out:
# year               2049
# combinedStatus     2049
# gender             1475
# type               2049
# typeOfDeath        1382
# status             2049
# employedAs         2041
# jobs               1413
# coverage           1360
# mediums            1410
# country            2049
# location           2034
# sourcesOfFire      1205
# motiveConfirmed    1935
# dtype: int64

# %%
# Create a query of DF for years greater than 2014 ..result should be years 2015 -2020
journal_by_years = journal_death_dropfour_df.query('year > 2014')
journal_by_years
# Out:
#       year combinedStatus  gender          type           typeOfDeath  status  \
# 0     2018      Confirmed    Male    Journalist                Murder  Killed
# 12    2016      Confirmed    Male    Journalist             Crossfire  Killed
# 14    2016      Confirmed    Male    Journalist                Murder  Killed
# 16    2019      Confirmed    Male    Journalist  Dangerous Assignment  Killed
# 22    2020      Confirmed    Male    Journalist                Murder  Killed
# ...    ...            ...     ...           ...                   ...     ...
# 2021  2015      Confirmed     NaN  Media Worker                   NaN  Killed
# 2028  2017      Confirmed    Male  Media Worker                   NaN  Killed
# 2032  2018      Confirmed  Female  Media Worker                   NaN  Killed
# 2041  2018         Killed    Male  Media Worker                   NaN  Killed
# 2047  2017      Confirmed    Male  Media Worker                   NaN  Killed
#
#      employedAs                                             jobs  \
# 0         Staff                                         Producer
# 12        Staff                     Camera Operator,Photographer
# 14        Staff                               Broadcast Reporter
# 16        Staff               Broadcast Reporter,Camera Operator
# 22    Freelance  Broadcast Reporter,Camera Operator,Photographer
# ...         ...                                              ...
# 2021      Staff                                              NaN
# 2028        NaN                                              NaN
# 2032      Staff                                              NaN
# 2041      Staff                                              NaN
# 2047        NaN                                              NaN
#
#                          coverage           mediums      country  \
# 0              Crime,Politics,War    Radio,Internet  Afghanistan
# 12                            War  Print,Television        Libya
# 14    Corruption,Human Rights,War             Radio      Somalia
# 16                            War    Radio,Internet      Somalia
# 22      Human Rights,Politics,War  Radio,Television      Somalia
# ...                           ...               ...          ...
# 2021                          NaN               NaN        Yemen
# 2028                          NaN               NaN  Afghanistan
# 2032                          NaN               NaN          USA
# 2041                          NaN               NaN     Ethiopia
# 2047                          NaN               NaN  Afghanistan
#
#                  location    sourcesOfFire motiveConfirmed
# 0                   Kabul  Political Group       Confirmed
# 12                  Sirte  Political Group       Confirmed
# 14              Mogadishu  Political Group       Confirmed
# 16              Awdheegle  Political Group       Confirmed
# 22                Afgooye  Political Group       Confirmed
# ...                   ...              ...             ...
# 2021               Sana'a              NaN             NaN
# 2028                  NaN              NaN             NaN
# 2032  Annapolis, Maryland  Local Residents             NaN
# 2041                Meiso              NaN             NaN
# 2047            Jalalabad              NaN             NaN
#
# [422 rows x 14 columns]

# %%
marks_list = journal_by_years['year'].tolist() 
  
# show the list 
print(marks_list)
# Out:
# [2018, 2016, 2016, 2019, 2020, 2017, 2019, 2018, 2020, 2018, 2016, 2018, 2018, 2016, 2015, 2017, 2018, 2015, 2015, 2015, 2016, 2020, 2015, 2018, 2016, 2018, 2019, 2015, 2019, 2016, 2017, 2019, 2018, 2016, 2017, 2016, 2018, 2015, 2016, 2020, 2019, 2015, 2015, 2019, 2018, 2017, 2015, 2015, 2016, 2018, 2018, 2015, 2015, 2015, 2015, 2015, 2018, 2017, 2018, 2020, 2017, 2017, 2015, 2015, 2017, 2015, 2016, 2018, 2017, 2015, 2017, 2017, 2019, 2016, 2016, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2019, 2017, 2015, 2015, 2018, 2015, 2020, 2018, 2015, 2015, 2017, 2018, 2017, 2016, 2016, 2017, 2015, 2019, 2015, 2017, 2015, 2018, 2016, 2015, 2015, 2015, 2018, 2015, 2015, 2018, 2018, 2017, 2015, 2018, 2016, 2016, 2016, 2017, 2018, 2015, 2018, 2015, 2019, 2020, 2020, 2015, 2018, 2018, 2017, 2016, 2015, 2017, 2015, 2016, 2016, 2017, 2018, 2016, 2018, 2019, 2018, 2017, 2020, 2015, 2017, 2019, 2015, 2016, 2018, 2016, 2016, 2017, 2020, 2018, 2017, 2016, 2020, 2017, 2017, 2019, 2019, 2015, 2018, 2016, 2018, 2015, 2016, 2016, 2019, 2016, 2016, 2015, 2016, 2015, 2018, 2015, 2015, 2016, 2016, 2018, 2020, 2016, 2015, 2018, 2019, 2019, 2017, 2015, 2016, 2019, 2015, 2018, 2015, 2019, 2018, 2018, 2018, 2017, 2016, 2017, 2020, 2018, 2016, 2015, 2019, 2017, 2018, 2019, 2016, 2017, 2018, 2015, 2020, 2018, 2016, 2015, 2019, 2018, 2020, 2016, 2016, 2018, 2017, 2016, 2016, 2018, 2019, 2018, 2017, 2017, 2015, 2020, 2018, 2017, 2016, 2017, 2020, 2018, 2016, 2018, 2015, 2017, 2015, 2017, 2017, 2017, 2016, 2017, 2017, 2015, 2015, 2019, 2019, 2017, 2017, 2015, 2015, 2018, 2015, 2017, 2018, 2018, 2015, 2016, 2016, 2015, 2015, 2015, 2018, 2018, 2016, 2018, 2018, 2016, 2015, 2016, 2016, 2020, 2016, 2016, 2018, 2016, 2020, 2017, 2019, 2020, 2019, 2017, 2017, 2017, 2015, 2015, 2016, 2019, 2015, 2019, 2019, 2015, 2018, 2017, 2017, 2016, 2015, 2015, 2020, 2016, 2018, 2015, 2017, 2018, 2015, 2016, 2019, 2018, 2017, 2017, 2016, 2015, 2016, 2018, 2016, 2018, 2019, 2016, 2020, 2019, 2015, 2020, 2018, 2018, 2015, 2019, 2016, 2018, 2017, 2020, 2017, 2019, 2016, 2017, 2018, 2016, 2016, 2015, 2019, 2015, 2020, 2015, 2017, 2017, 2016, 2016, 2016, 2019, 2017, 2016, 2018, 2019, 2017, 2015, 2016, 2020, 2019, 2015, 2019, 2015, 2016, 2015, 2019, 2015, 2015, 2017, 2019, 2019, 2019, 2018, 2015, 2019, 2016, 2019, 2019, 2019, 2015, 2019, 2017, 2018, 2017, 2018, 2017, 2016, 2016, 2018, 2018, 2018, 2020, 2019, 2018, 2017, 2018, 2016, 2015, 2017, 2017, 2018, 2017, 2015, 2018, 2018, 2016, 2018, 2018, 2018, 2017, 2017, 2015, 2017, 2018, 2018, 2017]

# %%
journal_by_years.dtypes
# Out:
# year                int64
# combinedStatus     object
# gender             object
# type               object
# typeOfDeath        object
# status             object
# employedAs         object
# jobs               object
# coverage           object
# mediums            object
# country            object
# location           object
# sourcesOfFire      object
# motiveConfirmed    object
# dtype: object

# %%
sort_by_year = journal_by_years.sort_values('year')
sort_by_year
# Out:
#       year combinedStatus gender        type typeOfDeath  status employedAs  \
# 1522  2015    Unconfirmed    NaN  Journalist         NaN  Killed      Staff
# 398   2015      Confirmed   Male  Journalist      Murder  Killed      Staff
# 392   2015      Confirmed   Male  Journalist      Murder  Killed      Staff
# 388   2015      Confirmed   Male  Journalist      Murder  Killed      Staff
# 384   2015      Confirmed   Male  Journalist      Murder  Killed      Staff
# ...    ...            ...    ...         ...         ...     ...        ...
# 1631  2020    Unconfirmed   Male  Journalist         NaN  Killed      Staff
# 1670  2020    Unconfirmed   Male  Journalist         NaN  Killed      Staff
# 459   2020      Confirmed   Male  Journalist      Murder  Killed      Staff
# 1193  2020      Confirmed   Male  Journalist      Murder  Killed      Staff
# 1766  2020    Unconfirmed   Male  Journalist         NaN  Killed      Staff
#
#                                              jobs  \
# 1522                                          NaN
# 398                                      Producer
# 392                               Publisher/Owner
# 388   Columnist/Commentator,Editor,Print Reporter
# 384                             Internet Reporter
# ...                                           ...
# 1631                                          NaN
# 1670                            Internet Reporter
# 459                            Broadcast Reporter
# 1193                                   Technician
# 1766                              Publisher/Owner
#
#                                   coverage         mediums      country  \
# 1522                                   NaN             NaN    Guatemala
# 398   Corruption,Human Rights,Politics,War  Print,Internet       Turkey
# 392                                    NaN           Print   Bangladesh
# 388   Corruption,Human Rights,Politics,War           Print         Iraq
# 384                       Corruption,Crime        Internet       Brazil
# ...                                    ...             ...          ...
# 1631                                   NaN             NaN    Venezuela
# 1670                                   NaN        Internet       Brazil
# 459                                    NaN      Television     Honduras
# 1193                 Business,Politics,War      Television  Afghanistan
# 1766                              Politics      Television         Iraq
#
#            location                       sourcesOfFire motiveConfirmed
# 1522    Mazatenango                                 NaN     Unconfirmed
# 398            Urfa                     Political Group       Confirmed
# 392          Dhaka                      Political Group       Confirmed
# 388           Mosul                     Political Group       Confirmed
# 384   Padre Paraíso                      Criminal Group       Confirmed
# ...             ...                                 ...             ...
# 1631         Güiria                                 NaN     Unconfirmed
# 1670       Araruama                                 NaN     Unconfirmed
# 459        La Ceiba                      Criminal Group       Confirmed
# 1193          Kabul                     Political Group       Confirmed
# 1766        Baghdad  Paramilitary Group,Political Group     Unconfirmed
#
# [422 rows x 14 columns]

# %%
sort_by_year['country']=="United States"
# Out:
# 1522    False
# 398     False
# 392     False
# 388     False
# 384     False
#         ...
# 1631    False
# 1670    False
# 459     False
# 1193    False
# 1766    False
# Name: country, Length: 422, dtype: bool
